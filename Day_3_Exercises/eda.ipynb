# %% [markdown]
# # This is a title
#
# ## This is a subtitle
#
# These are notes:
#
# - Download CSV files from Nirosh Repo
# - Load into notebook using pandas
# - Clean the CSV's
# - Output clean files

# %%
import pandas as pd
Customers = pd.read_csv("03_Library SystemCustomers.csv")

# %%
print(Customers.head)
# Out:
# <bound method NDFrame.head of    Customer ID     Customer Name
# 0          1.0          Jane Doe
# 1          2.0        John Smith
# 2          3.0        Dan Reeves
# 3          NaN               NaN
# 4          5.0    William Holden
# 5          6.0     Jaztyn Forest
# 6          7.0     Jackie Irving
# 7          8.0  Matthew Stirling
# 8          9.0         Emory Ted>

# %%
Customers.shape
# Out:
# (9, 2)

# %%
print(Customers.shape)
# Out:
# (9, 2)

# %%
print(Customers.info)
# Out:
# <bound method DataFrame.info of    Customer ID     Customer Name
# 0          1.0          Jane Doe
# 1          2.0        John Smith
# 2          3.0        Dan Reeves
# 3          NaN               NaN
# 4          5.0    William Holden
# 5          6.0     Jaztyn Forest
# 6          7.0     Jackie Irving
# 7          8.0  Matthew Stirling
# 8          9.0         Emory Ted>

# %%
print(Customers.isna().sum().sort_values(ascending=False))
# Out:
# Customer ID      1
# Customer Name    1
# dtype: int64

# %%
CleanCustomers = Customers.drop(index=3)

# %%
print(CleanCustomers.info)
# Out:
# <bound method DataFrame.info of    Customer ID     Customer Name
# 0          1.0          Jane Doe
# 1          2.0        John Smith
# 2          3.0        Dan Reeves
# 4          5.0    William Holden
# 5          6.0     Jaztyn Forest
# 6          7.0     Jackie Irving
# 7          8.0  Matthew Stirling
# 8          9.0         Emory Ted>

# %%
from pathlib import Path
out = Path(r"C:\Users\Admin\Desktop\20260817-Module5\CleanCustomers.csv")
CleanCustomers.to_csv(out, index=False, encoding="utf-8-sig")

# %%
Books = pd.read_csv("03_Library Systembook.csv")

# %%
print(Books.info)
# Out:
# <bound method DataFrame.info of       Id                                     Books Book checkout  \
# 0    1.0                       Catcher in the Rye   "20/02/2023"
# 1    2.0          Lord of the rings the two towers  "24/03/2023"
# 2    3.0  Lord of the rings the return of the kind  "29/03/2023"
# 3    4.0                                The hobbit  "02/04/2023"
# 4    5.0                                     Dune   "02/04/2023"
# ..   ...                                       ...           ...
# 109  NaN                                       NaN           NaN
# 110  NaN                                       NaN           NaN
# 111  NaN                                       NaN           NaN
# 112  NaN                                       NaN           NaN
# 113  NaN                                       NaN           NaN
#
#     Book Returned Days allowed to borrow  Customer ID
# 0      25/02/2023                2 weeks          1.0
# ...

# %%
Books['Book checkout'] = Books['Book checkout'].str.replace('"', '', regex=False)

# %%
print(Books.info)
# Out:
# <bound method DataFrame.info of       Id                                     Books Book checkout  \
# 0    1.0                       Catcher in the Rye     20/02/2023
# 1    2.0          Lord of the rings the two towers    24/03/2023
# 2    3.0  Lord of the rings the return of the kind    29/03/2023
# 3    4.0                                The hobbit    02/04/2023
# 4    5.0                                     Dune     02/04/2023
# ..   ...                                       ...           ...
# 109  NaN                                       NaN           NaN
# 110  NaN                                       NaN           NaN
# 111  NaN                                       NaN           NaN
# 112  NaN                                       NaN           NaN
# 113  NaN                                       NaN           NaN
#
#     Book Returned Days allowed to borrow  Customer ID
# 0      25/02/2023                2 weeks          1.0
# ...

# %%
Books2 = Books[Books["Id"]<20]

# %%
Books2.head
# Out:
# <bound method NDFrame.head of       Id                                     Books Book checkout  \
# 0    1.0                       Catcher in the Rye     20/02/2023
# 1    2.0          Lord of the rings the two towers    24/03/2023
# 2    3.0  Lord of the rings the return of the kind    29/03/2023
# 3    4.0                                The hobbit    02/04/2023
# 4    5.0                                     Dune     02/04/2023
# 5    6.0                              Little Women    02/04/2023
# 6    7.0                                        IT    10/04/2063
# 7    8.0                                   Misery     15/04/2023
# 8    9.0                                  Catch 22    15/04/2023
# 9   10.0                              Animal Farm     20/04/2023
# 10  11.0                                      1984    23/04/2023
# 11  12.0                              Little Women    02/04/2023
# 12  13.0                              East of Eden    30/04/2023
# ...

# %%
# Functions Recap
def sayHello():
    print("Hello")

sayHello()
# Out:
# Hello

# %%
Books2.columns = (
    Books2.columns
      .str.strip()
      .str.lower()
      .str.replace(r"[^\w]+", "_", regex=True)   # spaces, dashes, punctuation → _
      .str.strip("_")
)

# %%
Books2.info
# Out:
# <bound method DataFrame.info of       id                                     books book_checkout  \
# 0    1.0                       Catcher in the Rye     20/02/2023
# 1    2.0          Lord of the rings the two towers    24/03/2023
# 2    3.0  Lord of the rings the return of the kind    29/03/2023
# 3    4.0                                The hobbit    02/04/2023
# 4    5.0                                     Dune     02/04/2023
# 5    6.0                              Little Women    02/04/2023
# 6    7.0                                        IT    10/04/2063
# 7    8.0                                   Misery     15/04/2023
# 8    9.0                                  Catch 22    15/04/2023
# 9   10.0                              Animal Farm     20/04/2023
# 10  11.0                                      1984    23/04/2023
# 11  12.0                              Little Women    02/04/2023
# 12  13.0                              East of Eden    30/04/2023
# ...

# %%
from pathlib import Path
out = Path(r"C:\Users\Admin\Desktop\20260817-Module5\CleanBooks.csv")
Books2.to_csv(out, index=False, encoding="utf-8-sig")

# %%
Books2.drop(index=16, inplace=True)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_5984\2471784872.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   CleanBooks = Books2.drop(index=16, inplace=True)

# %%
# Out:
# <bound method DataFrame.info of       id                                     books book_checkout  \
# 0    1.0                       Catcher in the Rye     20/02/2023
# 1    2.0          Lord of the rings the two towers    24/03/2023
# 2    3.0  Lord of the rings the return of the kind    29/03/2023
# 3    4.0                                The hobbit    02/04/2023
# 4    5.0                                     Dune     02/04/2023
# 5    6.0                              Little Women    02/04/2023
# 6    7.0                                        IT    10/04/2063
# 7    8.0                                   Misery     15/04/2023
# 8    9.0                                  Catch 22    15/04/2023
# 9   10.0                              Animal Farm     20/04/2023
# 10  11.0                                      1984    23/04/2023
# 11  12.0                              Little Women    02/04/2023
# 12  13.0                              East of Eden    30/04/2023
# ...

# %%
def days_between(df, start_col, end_col, new_col="days_between"):
    """Add a column holding the whole-day difference between two date columns."""
    start = pd.to_datetime(df[start_col], dayfirst=True, errors="coerce")
    end   = pd.to_datetime(df[end_col],   dayfirst=True, errors="coerce")

    df = df.copy()
    df[new_col] = (end - start).dt.days
    return df


Books2 = days_between(Books2, "book_checkout", "book_returned", "days_borrowed")

Books2[["book_checkout", "book_returned", "days_borrowed"]].head(10)
# Out:
#   book_checkout book_returned  days_borrowed
# 0    20/02/2023    25/02/2023              5
# 1    24/03/2023    21/03/2023             -3
# 2    29/03/2023    25/03/2023             -4
# 3    02/04/2023    25/03/2023             -8
# 4    02/04/2023    25/03/2023             -8
# 5    02/04/2023    01/05/2023             29
# 6    10/04/2063    03/04/2023         -14617
# 7    15/04/2023    03/04/2023            -12
# 8    15/04/2023    16/04/2023              1
# 9    20/04/2023    24/04/2023              4

# %%
Books2.head
# Out:
# <bound method NDFrame.head of       id                                     books book_checkout  \
# 0    1.0                       Catcher in the Rye     20/02/2023
# 1    2.0          Lord of the rings the two towers    24/03/2023
# 2    3.0  Lord of the rings the return of the kind    29/03/2023
# 3    4.0                                The hobbit    02/04/2023
# 4    5.0                                     Dune     02/04/2023
# 5    6.0                              Little Women    02/04/2023
# 6    7.0                                        IT    10/04/2063
# 7    8.0                                   Misery     15/04/2023
# 8    9.0                                  Catch 22    15/04/2023
# 9   10.0                              Animal Farm     20/04/2023
# 10  11.0                                      1984    23/04/2023
# 11  12.0                              Little Women    02/04/2023
# 12  13.0                              East of Eden    30/04/2023
# ...

# %%
from Clean_Customers import main

main()
# Out:
# Loaded 114 rows from 03_Library Systembook.csv
# Removed 92 duplicate rows
# Removed 2 rows with missing values
# wrote 20 cleans rowns to C:\Users\Admin\Desktop\20260817-Module5\03_Library Systembook Cleaned.csv

# %%
# %load_ext autoreload
# %autoreload 2

from Clean_Customers import main
main()
# Out:
# Loaded 114 rows from 03_Library Systembook.csv
# Removed 92 duplicate rows
# Removed 2 rows with missing values
# wrote 20 cleans rowns to C:\Users\Admin\Desktop\20260817-Module5\03_Library Systembook Cleaned.csv

# %%
import importlib
import Clean_Customers

importlib.reload(Clean_Customers)
from Clean_Customers import CleanCustomers

CleanCustomers()
# Out:
# Loaded 9 rows from 03_Library SystemCustomers.csv
# Removed 0 duplicate rows
# Removed 1 rows with missing values
# wrote 8 cleans rowns to C:\Users\Admin\Desktop\20260817-Module5\03_Library SystemCustomers Cleaned.csv

# %%
from Clean_Customers import CleanBooks 
from Clean_Customers import CleanCustomers

CleanBooks()
CleanCustomers()
# Out:
# Loaded 114 rows from C:\Users\Admin\Desktop\20260817-Module5\03_Library Systembook.csv
# Removed 92 duplicate rows
# Removed 2 rows with missing values
# wrote 20 cleans rows to C:\Users\Admin\Desktop\20260817-Module5\03_Library SystemBook Cleaned.csv
# Loaded 9 rows from 03_Library SystemCustomers.csv
# Removed 0 duplicate rows
# Removed 1 rows with missing values
# wrote 8 cleans rows to C:\Users\Admin\Desktop\20260817-Module5\03_Library SystemCustomers Cleaned.csv
